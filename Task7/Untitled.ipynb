# %%
import numpy as np
from numpy import linalg as la

x = np.array([1.2, 2.0, 3.1, 4.4, 4.9, 5.8, 6.9, 8.0, 9.1, 9.9])
y = np.array([0.3, 0.5, 0.7, 0.8, 1.3, 1.6, 2.0, 2.3, 2.9, 3.0])

# Use function numpy.linalg.solve() to find the coefficients of the interpolating polynomial that goes through all these data points.
a = np.linalg.solve(x, y)
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Software/users/modules/9/software/anaconda3/2025.06/lib/python3.13/site-packages/numpy/linalg/_linalg.py:259, in _assert_stacked_square(*arrays)
#     258 try:
# --> 259     m, n = a.shape[-2:]
#     260 except ValueError:
#
# ValueError: not enough values to unpack (expected 2, got 1)
#
# During handling of the above exception, another exception occurred:
#
# LinAlgError                               Traceback (most recent call last)
# Cell In[2], line 8
#       5 y = np.array([0.3, 0.5, 0.7, 0.8, 1.3, 1.6, 2.0, 2.3, 2.9, 3.0])
#       7 # Use function numpy.linalg.solve() to find the coefficients of the interpolating polynomial that goes through all these data points.
# ----> 8 a = np.linalg.solve(x, y)
#       9 print(a)
#
# File /Software/users/modules/9/software/anaconda3/2025.06/lib/python3.13/site-packages/numpy/linalg/_linalg.py:457, in solve(a, b)
#     384 """
#     385 Solve a linear matrix equation, or system of linear scalar equations.
#     386
#    (...)
#     454
#     455 """
#     456 a, _ = _makearray(a)
# --> 457 _assert_stacked_square(a)
#     458 b, wrap = _makearray(b)
#     459 t, result_t = _commonType(a, b)
#
# File /Software/users/modules/9/software/anaconda3/2025.06/lib/python3.13/site-packages/numpy/linalg/_linalg.py:261, in _assert_stacked_square(*arrays)
#     259     m, n = a.shape[-2:]
#     260 except ValueError:
# --> 261     raise LinAlgError('%d-dimensional array given. Array must be '
#     262             'at least two-dimensional' % a.ndim)
#     263 if m != n:
#     264     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: 1-dimensional array given. Array must be at least two-dimensional
