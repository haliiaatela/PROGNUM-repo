# %% [markdown]
# Answers for Week 1
#
# * Name: Halia
# * Username: hatela
# * Student s-number: S6250890
# * Group (AS1, etc.): AS1

# %% [markdown]
# question 1.2 (quiz)

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# question 1.3

# %%
x=6
x*=5
x*=4
x*=3
x*=2
x*=1
print (x)
# Out:
# 720

# %% [markdown]
# question 1.4

# %%
from scipy.constants import h
from scipy.constants import c

wavelenth= 

energy=

# %% [markdown]
# question 1.5 (quiz)

# %%
from scipy.constants import G

mass1= 7.342*10**22
mass2= 5.9722*10**24
r= 385.0006*10**6

Force= (G*mass1*mass2/r**2)

print (Force)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# question 1.10 (quiz)

# %% [markdown]
# ![image.png](attachment:8ab0796a-91d6-4eb8-b79b-c8210da86fd2.png)

# %% [markdown]
# question 1.11 (quiz)

# %% [markdown]
# ![Screenshot 2026-02-12 at 21.34.49.png](attachment:f798a1b2-0f7a-45cf-8568-9c705d5460fb.png)

# %% [markdown]
# question 1.12 (quiz)

# %% [markdown]
# ![Screenshot 2026-02-12 at 21.59.37.png](attachment:ecb045e8-d726-4587-a780-742577626804.png)

# %% [markdown]
# question 1.15 (quiz)

# %% [markdown]
# pwd: print the absolute path (if you imagine a tree it is like going to the root)
# .: current directory
# ..: one step back

# %% [markdown]
# question 1.16 (quiz)

# %%
cd ~/Desktop
# Out:
# /Users/users/hatela/Desktop

# %% [markdown]
# question 1.19 (quiz)
