# %%
from math import exp, log

x = 7

result = exp(log(x))

print(result)
# Out:
# 6.999999999999999

# %%
from math import atan2, degrees, tan

x = 2
y = 3

phi_deg = degrees(atan2(x, y))

print (f"phi degrees: {phi_deg}")

print(tan(phi_deg)) == print(x / y)
# Out:
# phi degrees: 33.690067525979785
# -1.1792145672813943
# 0.6666666666666666
# True

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143

# %%
# fibonnacci

# %%
# sequences

lala = []
lala.append(1)
lala.append (6)
lala.append (10)
lala.append (12)
lala.append (13)

print("list =", lala)
# Out:
# list = [1, 6, 10, 12, 13]

# %%
x = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]

x.append(0.51)
x.remove(2.12)

N = len(x)

print("N = ", N)
print(x)


# indexes
# The first element has index

# The second has index 1 etc

# The last element has index -1

# The forelast element has index -2 etc

string = "tengo un examen"

print(string[0])
print(string[5])
print(string[-2])

# slicingg: extracting parts of a sequence

x = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]
print(x[:])

sli_ce = x[2:9]
print("slice =", sli_ce)

# print x[2:9]

_sum = sum(x[2:9])
print(_sum)
# Out:
# N =  10
# [1.36, 1.46, 1.41, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18, 0.51]
# t
#
# e
# [1.36, 1.46, 1.41, 2.12, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18]
# slice = [1.41, 2.12, 0.42, 0.98, 0.45, 1.97, -0.24]
# 7.11

# %%
# fibonnacci

fib = [1, 2]
for i in range(98):
    fib.append(fib[-1] + fib[-2])
print("100th term:", fib[99])
# Out:
# 100th term: 573147844013817084101
